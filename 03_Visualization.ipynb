# %% [markdown]
# <img  src="https://media.mehrnews.com/d/2019/07/31/4/3194094.jpg">

# %% [markdown]
# <h1>Data Visualization<span class="tocSkip"></span></h1>

# %% [markdown]
# # Import

# %% [markdown]
# ## libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import numpy

# %% [markdown]
# ## DataFrame

# %%
data = pd.read_csv("data/cars_limpio.csv")

# %% [markdown]
# # Preliminary conclusions

# %% [markdown]
# # Type of fuel

# %%
fig = plt.figure(figsize=(15, 10))
plt.xticks(rotation=45)
cons = sns.countplot(x=data.consume, hue=data.gas_type, palette="flare")

# %%
vt.guarda_grafico(riesgo_muerte, "images/riesgo_muerto.svg")

# %% [markdown]
# # Price per travel

# %% [markdown]
# # Distance
